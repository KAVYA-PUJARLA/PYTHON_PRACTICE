# %%
a = [1,2,3,4]
print(a);
b=[1,2.5,True, "test"]
print(b) 
x=(1,2,3,4)
print(x)
y=(1,2.4,True,"Hi")
print(y)
# Out:
# [1, 2, 3, 4]
# [1, 2.5, True, 'test']
# (1, 2, 3, 4)
# (1, 2.4, True, 'Hi')

# %%
print(a[0])
print(a[1])
print(a[2])
print(a[3])

print(y[0])
print(y[1])
print(y[2])
print(y[3])
# Out:
# 1
# 2
# 3
# 4
# 1
# 2.4
# True
# Hi

# %%
#slicing
print(a[2:4:1])

print(a[::-1])
print(a[0::2])
# Out:
# [3, 4]
# [4, 3, 2, 1]
# [1, 3]

# %%
#converting tuple to list and list to tuple
x=[1,2,3]
y = tuple(x)
print(x)
print(y)

a = (1,2,3)
b = list(a)
print(a)
print(b)
# Out:
# [1, 2, 3]
# (1, 2, 3)
# (1, 2, 3)
# [1, 2, 3]

# %%
x=(1,2,3)
print(5 in x)
# Out:
# False

# %%
for number in x:
    print(number)
# Out:
# 1
# 2
# 3
