# %%
print('Hi')
# Out:
# Hi

# %%
max=1000
num = 0
sum=0
while num<max:
    if(num%3 == 0 or num %5==0):
        sum+=num
    num+=1   
print(sum)
# Out:
# 233168

# %%
first = 1
second= 2
num=50
print(first)
print(second)
while first+second < num:
    third = first+second
    print(third)
    first = second
    second = third
# Out:
# 1
# 2
# 3
# 5
# 8
# 13
# 21
# 34

# %%
number=20
index=2
while index < number:
    if(number % index == 0):
        print(index)
    index+=1
# Out:
# 2
# 4
# 5
# 10

# %%
def print_numbers(start,finish):
    while start<finish:
        print(start)
        start+=1

# %%
print_numbers(1,5)
# Out:
# 1
# 2
# 3
# 4
