# %%
x=5
y=3
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 2
# 125

# %%
x=2
x+=8
x
# Out:
# 10

# %%
x>4 and x<20
# Out:
# True

# %%
x>1 or x<10
# Out:
# True

# %%
weight_in_kilos=20
weight_in_pounds=2.204 * weight_in_kilos
weight_in_pounds
# Out:
# 44.080000000000005

# %%
x=20
x%2==0
# Out:
# True

# %%
x1=1
x2=2
x3='Hello'
x4='Hello'
x5=[1,2,3]
x6=[1,2,3]
print(x1 is x2)
# Out:
# False

# %%
print(x3 is x4)
print(x5 is x6)
# Out:
# True
# False
