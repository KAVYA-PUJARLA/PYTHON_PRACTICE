# %%
x=1
type(x)
# Out:
# int

# %%
y=10.2
type(y)
# Out:
# float

# %%
z=1+4j
type(z)
# Out:
# complex

# %%
x/0
x//0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 x/0
#       2 x//0
#
# ZeroDivisionError: division by zero
