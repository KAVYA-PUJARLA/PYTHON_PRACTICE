# %%
number = 10
result = number %2
if result == 0:
    print("even")
else:
    print('odd')
# Out:
# even

# %%
average = 60
if average > 70:
    print("Grade 1")
elif 60 <= average <70:
    print("Grade 2")
elif 50 <= average < 40:
    print("Grade 3")     
else:
    print("Grade 4")
# Out:
# Grade 2
