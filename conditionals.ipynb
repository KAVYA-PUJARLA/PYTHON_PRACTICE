# %%
number = 10
result = number %2
if result == 0:
    print("even")
else:
    print('odd')
# Out:
# even

# %%
average = 60
if average > 70:
    print("Grade 1")
elif 60 <= average <70:
    print("Grade 2")
elif 50 <= average < 40:
    print("Grade 3")     
else:
    print("Grade 4")
# Out:
# Grade 2

# %%
taxable_income=2000000
if taxable_income <=1200000:
    print("Hooray no tax")
else:
    tax=0
    if  taxable_income > 400000 :
        tax+=(400000*5/100)
    if taxable_income > 800000:
        max=1200000
        if taxable_income>max:
            tax = tax + (400000* 10  / 100)
        else:
            tax+=(max-taxable_income )* 10  / 100  
    if taxable_income > 120000:
        max=1600000
        if taxable_income>max:
            tax = tax + (400000* 15  / 100)
        else:
            tax+=(max-taxable_income )* 15  / 100
    if  taxable_income >1600000:
        max=2000000
        if taxable_income>max:
            tax = tax + (400000* 20  / 100)
        else:
            tax+=(max-taxable_income )* 20  / 100  
    if  taxable_income > 2000000:
        max=2400000
        if taxable_income>max:
            tax = tax + (400000* 25  / 100)
        else:
            tax+=(max-taxable_income )* 25  / 100   
        if  taxable_income > 2400000:
                tax+=(max-2400000 )* 30/100     
    print(tax)
# Out:
# 120000.0

# %%
print('Hiii')
